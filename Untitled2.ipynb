# %%
Countries = {'usa', 'uk', 'france'}
capital = {'Washington Dc', 'London', 'Paris'}
print(f"The capital city of {list(Countries)[1]} is {list(capital)[1]}") ## list() can be used to convert sets to list
# Out:
# The capital city of uk is London
