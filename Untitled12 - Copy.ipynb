# %%
import pandas as pd

import pandas as pd

df = pd.read_json("file.json")
df.head()
df.columns
# Out:
# Index(['job_id', 'job_title', 'company_name', 'salary', 'location',
#        'description', 'industry_type', 'sub_classification', 'highlights',
#        'job_url', 'job_type', 'job_details', 'job_posting_time',
#        'company_size', 'company_description', 'job_rating',
#        'number_of_reviews', 'date_scraped', 'classified_job',
#        'updated_category', 'Unnamed: 20', 'extracted_tools_str',
#        'extracted_soft_skills_str', 'extracted_programming_languages_str',
#        'extracted_methods_frameworks_str'],
#       dtype='object')

# %%
df.head()
# Out:
#      job_id                                          job_title  \
# 0  82989580  2026 DXC Technology Graduate Program - Busines...
# 1  83356563        Technical Business Analyst - Power Platform
# 2  82989575  2026 DXC Technology Graduate Program - Busines...
# 3  83351611      Senior Business Analyst - Fixed Term Contract
# 4  83355591                            Senior Business Analyst
#
#                  company_name                                  salary  \
# 0              GradConnection                                    None
# 1                        KPMG  Our people build skills for the future
# 2              GradConnection                                    None
# 3               Culture Kings                                    None
# 4  Australian Vintage Limited                                    None
#
#                   location                                        description  \
# 0              Adelaide SA  Our Graduate Program is designed for graduates...
# ...

# %%
df.job_details
# Out:
# 0       {"Our Graduate Program is designed for talente...
# 1       {"Job DescriptionOur Enterprise Technology Adv...
# 2       {"Our Graduate Program is designed for talente...
# 3       {"\nKey Responsibilites\nLead discovery worksh...
# 4       {"About AV:Australian Vintage (AV) is an ASX-l...
#                               ...
# 1554    {"This well known and prestigious Investment M...
# 1555                                                 {NA}
# 1556                                                 {NA}
# 1557    {"Business Analyst - Regulatory Transformation...
# 1558    {"About UsWe are Wipro (NYSE: WIT), a rapidly ...
# Name: job_details, Length: 1559, dtype: object
