# %%
import pandas as pd
import numpy as np
frame = pd.DataFrame(np.arange(-1,16).reshape((4,4)),
index=['red', 'blue', 'yellow', 'white'],
columns=['ball', 'pen', 'pencil', 'paper'])
np.sqrt(frame)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-ea50957cc487> in <cell line: 3>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 frame = pd.DataFrame(np.arange(-1,16).reshape((4,4)),
#       4 index=['red', 'blue', 'yellow', 'white'],
#       5 columns=['ball', 'pen', 'pencil', 'paper'])
#
# ValueError: cannot reshape array of size 17 into shape (4,4)
